# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\Aritro Saha\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO('yolov8n.pt')
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n.pt to 'yolov8n.pt': 100% ━━━━━━━━━━━━ 6.2MB 1.3MB/s 4.7s 4.6s<1.5ssss

# %%
image_path = "download.jpeg"  
results = model(image_path)

start_time = time.time()
results = model(img_cv)
end_time = time.time()

processing_time = end_time - start_time
print(f"Processing time: {processing_time:.3f} seconds")

r = results[0]

for r in results:
    annotated_img = r.plot()  # Draw boxes
    plt.figure(figsize=(10, 6))
    plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.show()
# Out:
# image 1/1 C:\python\Aritro_Saha_500119152\download.jpeg: 448x640 65 cars, 141.3ms
# Speed: 1.8ms preprocess, 141.3ms inference, 5.1ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 448x640 38 cars, 1 bus, 123.0ms
# Speed: 2.6ms preprocess, 123.0ms inference, 8.3ms postprocess per image at shape (1, 3, 448, 640)
# Processing time: 0.136 seconds

# %%
import cv2
import requests
import numpy as np
from PIL import Image
import io
import matplotlib.pyplot as plt
from ultralytics import YOLO

import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
from ultralytics import YOLO
import time

model = YOLO('yolov8n.pt')

image_path = "second_image.jpg"  
img = Image.open(image_path).convert('RGB')
img_cv = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)

start_time = time.time()
results = model(img_cv)
end_time = time.time()

processing_time = end_time - start_time
print(f"Processing time: {processing_time:.3f} seconds")

r = results[0]

annotated_img = r.plot()
plt.imshow(cv2.cvtColor(annotated_img, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

for box in r.boxes:
    cls_id = int(box.cls[0])
    conf = float(box.conf[0])
    label = model.names[cls_id]
    print(f"{label}: {conf:.2f}")
# Out:
# 0: 448x640 38 cars, 1 bus, 88.1ms
# Speed: 1.8ms preprocess, 88.1ms inference, 7.8ms postprocess per image at shape (1, 3, 448, 640)
# Processing time: 0.162 seconds
# car: 0.74
# car: 0.74
# car: 0.73
# car: 0.71
# car: 0.71
# car: 0.70
# car: 0.70
# car: 0.67
# car: 0.66
# car: 0.65
# car: 0.64
# car: 0.61
# car: 0.61
# car: 0.56
# car: 0.56
# car: 0.56
# car: 0.52
# car: 0.50
# car: 0.49
# car: 0.49
# car: 0.48
# bus: 0.47
# car: 0.47
# car: 0.43
# car: 0.39
# car: 0.38
# car: 0.38
# car: 0.35
# car: 0.33
# car: 0.32
# car: 0.32
# car: 0.32
# car: 0.31
# car: 0.28
# car: 0.27
# car: 0.27
# car: 0.27
# car: 0.27
# car: 0.25
